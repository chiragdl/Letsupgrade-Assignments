# %% [markdown]
# #Let's upgrade Assignment 1
# ##calacuator

# %%
a = int(input("Enter the value for a : "))
b = int(input("Enter the value for b : "))
Sum = a + b 
Sub = a - b 
product = a * b 
div = a / b 
print("Sum of a & b : " ,Sum)
print("Sum of a & b : " ,Sub)
print("Sum of a & b : " ,product)
print("Sum of a & b : " ,div)
# Out:
# Enter the value for a : 44
# Enter the value for b : 66
# Sum of a & b :  110
# Sum of a & b :  -22
# Sum of a & b :  2904
# Sum of a & b :  0.6666666666666666
